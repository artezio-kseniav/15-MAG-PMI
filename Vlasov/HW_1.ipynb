# %%
from sklearn.feature_extraction.text import TfidfVectorizer as tf_idf
from sklearn.datasets import fetch_20newsgroups
from sklearn.cluster import k_means


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = fetch_20newsgroups(subset='all')
tf_idf = tf_idf().fit_transform(data.data)
label = k_means(tf_idf, len(data.target_names))[1]

# %%
svd = sklearn.decomposition.TruncatedSVD(2).fit_transform(tf_idf)

# %%
plot.figure(figsize = (20, 20))
plot.scatter(svd[:,0], svd[:,1], c=label, alpha=0.6)
plot.show()
pass

# %%
label_three = k_means(tf_idf, 3)[1]
plot.figure(figsize = (20, 20))
plot.scatter(svd[:,0], svd[:,1], c=label_three, alpha=0.6)
plot.show()
pass
